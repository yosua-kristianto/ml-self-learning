# %%
# !pip install tensorflow scikit-learn opencv-python numpy matplotlib tqdm

# %% [markdown]
# # CNN Scratch
#
# In endeavor finding the best model that fit for (Multi Label Image Classification Dataset)[https://www.kaggle.com/datasets/meherunnesashraboni/multi-label-image-classification-dataset/data], building CNN model from scratch was made. The work employing Tensorflow's deep learning backend with Keras's API.
#
# The process to make the model is as follow:
#
# 1. Dataset Pre-Processing
# 2. Dataset Loading
# 3. Model Architecture
# 4. Training the Model
# 5. Model Evaluation

# %% [markdown]
# ## 1. Dataset Pre-Processing
#
# The downloaded dataset structure as follow:
#
# 1. multilabel_classification.csv
# 2. multilabel_classification(2).csv
# 3. multilabel_classification(6)-reduced_modified.csv
# 4. multilabel_classification(7).csv
# 5. /images
#
# During manual exploration, it is found there are 7844 images in total. So it is expected that the csv file, must also consist of only 7844 rows. With this requirement, the `multilabel_classification(6)-reduced_modified.csv` is chosen for its validity.
#
# In dataset pre-processing endeavor, the more precise data integrity checks is conducted. This to ensure the registered label within csv file is 1:1 with the image within `/images` folder.

# %%
import pandas;
import os;
import pathlib;
from tqdm import tqdm;
import numpy;

# %%
from google.colab import drive;
drive.mount('/content/drive');
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load csv file
# dataframe = pandas.read_csv("/Users/yosuakristianto/Documents/Dataset Repository/FIN DL/Number 1/multilabel_classification(6)-reduced_modified.csv");
# dataframe = pandas.read_csv("D:\\tDatase\\FIN DL\\Number 1\\multilabel_classification(6)-reduced_modified.csv");
dataframe = pandas.read_csv("/content/drive/MyDrive/Collab Dataset/FIN DL/Number 1/multilabel_classification(6)-reduced_modified.csv");

# %%
# Integrity checking initialization
# image_folder_path = "/Users/yosuakristianto/Documents/Dataset Repository/FIN DL/Number 1/images/";
# image_folder_path = "D:\\tDatase\\FIN DL\\Number 1\\images\\";
image_folder_path = "/content/drive/MyDrive/Collab Dataset/FIN DL/Number 1/images/";

# %%
# Starts integrity checking
print("Data integrity checking -", end = " ");

# Check for image data that not exist in the folder but exist in csv
not_found_image = [];

for idx, row in tqdm(dataframe.iterrows()):
    if(not os.path.exists(path = image_folder_path + row["Image_Name"])):
        not_found_image.append(idx);

# Check for duplicated image name data in csv
dataframe = dataframe.drop_duplicates(subset = ["Image_Name"]);

dataframe.shape, len(not_found_image)
# Out:
# Data integrity checking -
# 7943it [00:01, 4449.48it/s]
# ((7843, 12), 0)

# %% [markdown]
# ## 2. Data Loading
#
# With no not found image came from csv file, further steps to do data pre-processing is unnecessary. The step continue to data loading. Data loading part consist of these process below:
#
# 1. Load image data from disk as NumPy array
# Why? Because the deep learning model cannot directly read the image file. Instead, image convertion into HWC (Height-Width-Channel) array format, where every channels contains RGB color value.
#
# Since the csv and image files are separated entity, sorting image files by its name is conducted for both csv and the image folder during data loading
#
# 2. Resize all images into 224 x 224 pixel
#
# 3. Define feature - label for every loaded image data to replace the image name.
#
# 4. Train-Test-Val splits
#
# The splits ratio is 70:30:30
#
# 5. Data Loading Pattern
# Making data loading pattern for better batch data segmentation and transformation. This is necessary since the minimum image height is 33 and image width was 120. This can be done by standardizing all images to 224 x 224.

# %%
from sklearn.model_selection import train_test_split;
import cv2;

# %%
# Load image data from disk as NumPy array

# Sort image file by name
list_files = os.listdir(image_folder_path);
list_files.sort()

images = [];

heights, widths = [], [];

for i in tqdm(list_files):
    image = cv2.imread(filename = image_folder_path + i);

    # Resize image to 224 x 224
    image = cv2.resize(image, (224, 224));

    images.append(image);

    height, width, channels = image.shape;

    heights.append(height);
    widths.append(width);

print(f"Minimal size: height: {min(heights)} - width: {min(widths)}");
# Out:
# 100%|██████████| 7843/7843 [02:26<00:00, 53.35it/s]
# Minimal size: height: 224 - width: 224

# %%
# Defining which is label and which is feature

# feature has been declared on the above cell as `images`
images = images;

# Convert dataframe's content by image name alp
sorted_dataframe = dataframe.sort_values(by=["Image_Name"], ascending=[True]);

# label
labels = sorted_dataframe.drop(columns = [" Classes(motorcycle, truck, boat, bus, cycle, , , , , , , sitar, ektara, flutes, tabla, harmonium)", "Image_Name"]);

(len(images)), labels.shape
# Out:
# (7843, (7843, 10))

# %%
# Train-Test-Split

# First to split it into 70:30
train_image, test_image, train_label, test_label = train_test_split(images, labels, train_size = 0.7, test_size = 0.3, random_state = 42);

# Since the test is already 30, then to make it 15:15 with val, we need to split it to 50:50
test_image, val_image, test_label, val_label = train_test_split(test_image, test_label, train_size = 0.5, test_size = 0.5, random_state = 42);

train_image = numpy.array(train_image);
test_image = numpy.array(test_image);
val_image = numpy.array(val_image);
train_label = train_label.to_numpy();
test_label = test_label.to_numpy();
val_label = val_label.to_numpy();

# %%
print("Training dataset shape: ")

print("Total dataset, width, height")

print(len(train_image), len(train_image[0]), len(train_image[0][0]))
print(len(train_label), len(train_label[0]));

print(len(test_image), len(test_image[0]), len(test_image[0][0]))
print(len(test_label), len(test_label[0]));

print(len(val_image), len(val_image[0]), len(val_image[0][0]))
print(len(val_label), len(val_label[0]));
# Out:
# Training dataset shape:
# Total dataset, width, height
# 5490 224 224
# 5490 10
# 1176 224 224
# 1176 10
# 1177 224 224
# 1177 10

# %%
# Helper Function
import requests;
import time;

# telegram_reporter
"""
This function helps to send message to telegram private channel
"""
def telegram_reporter(message):
    message = "[" + time.strftime("%Y-%m-%d %H:%M:%S") +"][CNN FROM SCRATCH] " + message
    requests.request(
        method="POST",
        url="https://api.telegram.org/bot6307342709:AAEehfQrvZzQhk2hFlOW7C1JnE2hRQYLEgE/sendMessage?chat_id=-1001525528850&text=" + message,
        headers={},
        data={}
    );

# %%
import tensorflow;
from tensorflow.keras.models import Sequential;
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization;
from tensorflow.keras.optimizers import Adam, SGD;
from tensorflow.keras.utils import plot_model;
from tensorflow.keras.callbacks import EarlyStopping;
from tensorflow.keras.regularizers import l2, l1_l2;

import matplotlib.pyplot as plt;

# %%
# Check whether the GPU is exist
tensorflow.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class CNNModel:

  def __init__(self):
    self.model_name = "cnn.scratch.202405302002";

    self.input = Input(shape = (224, 224, 3));
    self.conv1 = Conv2D(filters = 128, kernel_size = (3, 3), activation = "leaky_relu");
    self.pool1 = MaxPooling2D((2, 2));

    self.conv2 = Conv2D(filters = 256, kernel_size = (5, 5), activation = "leaky_relu");
    self.pool2 = MaxPooling2D((2, 2));

    self.conv3 = Conv2D(filters = 128, kernel_size = (3, 3), activation = "leaky_relu");
    self.pool3 = MaxPooling2D((3, 3));

    self.conv4 = Conv2D(filters = 64, kernel_size = (1, 1), activation = "leaky_relu");
    self.pool4 = MaxPooling2D((3, 3));

    # Fully Connected
    self.fullycon = Flatten();
    self.do1 = Dropout(0.5);

    # Dense Group
    self.dense1 = Dense(128, activation = "relu");
    self.bn1 = BatchNormalization();
    self.do2 = Dropout(0.5);


    self.dense2 = Dense(64, activation = "relu");
    self.bn2 = BatchNormalization();
    self.do3 = Dropout(0.3);

    self.output = Dense(10, activation = "sigmoid");

  # Early stopping after loss are not improved for some epochs
  def _callback_early_stopping(self):
      early_stopping_tolerance = 50;
      return EarlyStopping(
          monitor = "val_loss",
          patience = early_stopping_tolerance,
          restore_best_weights = True
      );

  def init_build(self):
    model = Sequential(name = self.model_name);

    model.add(self.input);

    model.add(self.conv1);
    model.add(self.pool1);

    model.add(self.conv2);
    model.add(self.pool2);

    model.add(self.conv3);
    model.add(self.pool3);

    model.add(self.conv4);
    model.add(self.pool4);

    model.add(self.fullycon);
    model.add(self.do1);

    model.add(self.dense1);
    model.add(self.bn1);
    model.add(self.do2);

    model.add(self.dense2);
    model.add(self.bn2);
    model.add(self.do3);

    model.add(self.output);

    return model;

  def fitting(self):
    model = self.init_build();

    # This technique will clip any exploding gradient. Not fixing the exploding gradient problem.
    model.compile(optimizer = Adam(learning_rate = 1e-3), loss = "binary_crossentropy", metrics = ["binary_accuracy"]);
    model.summary();

    plot_model(model, to_file = (f"model_architecture.{self.model_name}.png"), show_shapes = True);


    history = model.fit(
        train_image,
        train_label,
        epochs = 300,
        batch_size = 64,
        validation_data = (val_image, val_label),
        callbacks = [self._callback_early_stopping()]
    );

    # Plot training history
    plt.figure(figsize=(15, 12))

    # Loss
    plt.subplot2grid((3, 2), (0, 0));
    plt.plot(history.history['loss'], label='Training Loss');
    plt.plot(history.history['val_loss'], label='Validation Loss');
    plt.title('Loss Plots');
    plt.xlabel('Epoch');
    plt.ylabel('Loss');
    plt.legend();

    # Accuracy
    plt.subplot2grid((3, 2), (0, 1));
    plt.plot(history.history['binary_accuracy'], label='Training Binary Accuracy');
    plt.plot(history.history['val_binary_accuracy'], label='Validation Binary Accuracy');
    plt.title('Binary Accuracy Plots');
    plt.xlabel('Epoch');
    plt.ylabel('Binary Accuracy');
    plt.legend();

    plt.tight_layout();
    plt.show();

    return model;

# %%
# telegram_reporter("Starting training");

cnn = CNNModel();
model = cnn.fitting();

test_loss, test_acc = model.evaluate(test_image, test_label)
print(f'Test accuracy: {test_acc}')

# telegram_reporter("Training done");
# Out:
# Model: "cnn.scratch.202405302002"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 222, 222, 128)     3584
#
#  max_pooling2d_8 (MaxPoolin  (None, 111, 111, 128)     0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 107, 107, 256)     819456
#
#  max_pooling2d_9 (MaxPoolin  (None, 53, 53, 256)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 51, 51, 128)       295040
#
#  max_pooling2d_10 (MaxPooli  (None, 17, 17, 128)       0
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 17, 17, 64)        8256
#
#  max_pooling2d_11 (MaxPooli  (None, 5, 5, 64)          0
#  ng2D)
#
#  flatten_2 (Flatten)         (None, 1600)              0
#
#  dropout_5 (Dropout)         (None, 1600)              0
#
#  dense_6 (Dense)             (None, 128)               204928
#
#  batch_normalization_4 (Bat  (None, 128)               512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1340938 (5.12 MB)
# Trainable params: 1340554 (5.11 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________
# Epoch 1/300
# 86/86 [==============================] - 35s 270ms/step - loss: 0.7843 - binary_accuracy: 0.5621 - val_loss: 0.8975 - val_binary_accuracy: 0.4327
# Epoch 2/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.5768 - binary_accuracy: 0.7105 - val_loss: 0.5523 - val_binary_accuracy: 0.7535
# Epoch 3/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.4217 - binary_accuracy: 0.8357 - val_loss: 0.7833 - val_binary_accuracy: 0.6036
# Epoch 4/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.3747 - binary_accuracy: 0.8658 - val_loss: 0.5489 - val_binary_accuracy: 0.7839
# Epoch 5/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.3393 - binary_accuracy: 0.8752 - val_loss: 0.3126 - val_binary_accuracy: 0.8803
# Epoch 6/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.3179 - binary_accuracy: 0.8816 - val_loss: 0.3541 - val_binary_accuracy: 0.8750
# Epoch 7/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2990 - binary_accuracy: 0.8875 - val_loss: 0.3939 - val_binary_accuracy: 0.8307
# Epoch 8/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2847 - binary_accuracy: 0.8912 - val_loss: 0.3224 - val_binary_accuracy: 0.8807
# Epoch 9/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2674 - binary_accuracy: 0.8973 - val_loss: 0.6274 - val_binary_accuracy: 0.7937
# Epoch 10/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.3007 - binary_accuracy: 0.8864 - val_loss: 0.3726 - val_binary_accuracy: 0.8670
# Epoch 11/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2817 - binary_accuracy: 0.8925 - val_loss: 0.2560 - val_binary_accuracy: 0.9015
# Epoch 12/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2669 - binary_accuracy: 0.8977 - val_loss: 0.2987 - val_binary_accuracy: 0.8829
# Epoch 13/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2568 - binary_accuracy: 0.9009 - val_loss: 0.3114 - val_binary_accuracy: 0.8782
# Epoch 14/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2501 - binary_accuracy: 0.9034 - val_loss: 0.3084 - val_binary_accuracy: 0.8800
# Epoch 15/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2424 - binary_accuracy: 0.9062 - val_loss: 0.2985 - val_binary_accuracy: 0.8822
# Epoch 16/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2377 - binary_accuracy: 0.9074 - val_loss: 0.2107 - val_binary_accuracy: 0.9188
# Epoch 17/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2349 - binary_accuracy: 0.9091 - val_loss: 0.2175 - val_binary_accuracy: 0.9178
# Epoch 18/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2306 - binary_accuracy: 0.9103 - val_loss: 0.2241 - val_binary_accuracy: 0.9131
# Epoch 19/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2290 - binary_accuracy: 0.9107 - val_loss: 0.1972 - val_binary_accuracy: 0.9234
# Epoch 20/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2235 - binary_accuracy: 0.9120 - val_loss: 0.2133 - val_binary_accuracy: 0.9189
# Epoch 21/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2226 - binary_accuracy: 0.9138 - val_loss: 0.1994 - val_binary_accuracy: 0.9213
# Epoch 22/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2165 - binary_accuracy: 0.9150 - val_loss: 0.1903 - val_binary_accuracy: 0.9236
# Epoch 23/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2193 - binary_accuracy: 0.9140 - val_loss: 0.1881 - val_binary_accuracy: 0.9263
# Epoch 24/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2135 - binary_accuracy: 0.9172 - val_loss: 0.1882 - val_binary_accuracy: 0.9259
# Epoch 25/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2102 - binary_accuracy: 0.9171 - val_loss: 0.1905 - val_binary_accuracy: 0.9263
# Epoch 26/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2092 - binary_accuracy: 0.9179 - val_loss: 0.1809 - val_binary_accuracy: 0.9289
# Epoch 27/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2051 - binary_accuracy: 0.9195 - val_loss: 0.1802 - val_binary_accuracy: 0.9279
# Epoch 28/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2026 - binary_accuracy: 0.9204 - val_loss: 0.1854 - val_binary_accuracy: 0.9303
# Epoch 29/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1992 - binary_accuracy: 0.9216 - val_loss: 0.1745 - val_binary_accuracy: 0.9318
# Epoch 30/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1986 - binary_accuracy: 0.9223 - val_loss: 0.1718 - val_binary_accuracy: 0.9339
# Epoch 31/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1920 - binary_accuracy: 0.9252 - val_loss: 0.1671 - val_binary_accuracy: 0.9337
# Epoch 32/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1910 - binary_accuracy: 0.9258 - val_loss: 0.1645 - val_binary_accuracy: 0.9370
# Epoch 33/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1841 - binary_accuracy: 0.9281 - val_loss: 0.1565 - val_binary_accuracy: 0.9384
# Epoch 34/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1849 - binary_accuracy: 0.9281 - val_loss: 0.1570 - val_binary_accuracy: 0.9415
# Epoch 35/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2580 - binary_accuracy: 0.9034 - val_loss: 0.2646 - val_binary_accuracy: 0.9021
# Epoch 36/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2304 - binary_accuracy: 0.9103 - val_loss: 0.2577 - val_binary_accuracy: 0.8927
# Epoch 37/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2056 - binary_accuracy: 0.9198 - val_loss: 0.2203 - val_binary_accuracy: 0.9223
# Epoch 38/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1909 - binary_accuracy: 0.9262 - val_loss: 0.1728 - val_binary_accuracy: 0.9358
# Epoch 39/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1855 - binary_accuracy: 0.9282 - val_loss: 0.1595 - val_binary_accuracy: 0.9384
# Epoch 40/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1822 - binary_accuracy: 0.9293 - val_loss: 0.1602 - val_binary_accuracy: 0.9390
# Epoch 41/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1735 - binary_accuracy: 0.9324 - val_loss: 0.1595 - val_binary_accuracy: 0.9388
# Epoch 42/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1726 - binary_accuracy: 0.9331 - val_loss: 0.1431 - val_binary_accuracy: 0.9462
# Epoch 43/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1703 - binary_accuracy: 0.9343 - val_loss: 0.1517 - val_binary_accuracy: 0.9444
# Epoch 44/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1674 - binary_accuracy: 0.9357 - val_loss: 0.1416 - val_binary_accuracy: 0.9474
# Epoch 45/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1638 - binary_accuracy: 0.9360 - val_loss: 0.1407 - val_binary_accuracy: 0.9450
# Epoch 46/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1619 - binary_accuracy: 0.9384 - val_loss: 0.1561 - val_binary_accuracy: 0.9408
# Epoch 47/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1592 - binary_accuracy: 0.9385 - val_loss: 0.1423 - val_binary_accuracy: 0.9436
# Epoch 48/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1597 - binary_accuracy: 0.9387 - val_loss: 0.1398 - val_binary_accuracy: 0.9448
# Epoch 49/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1575 - binary_accuracy: 0.9400 - val_loss: 0.1292 - val_binary_accuracy: 0.9512
# Epoch 50/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1547 - binary_accuracy: 0.9403 - val_loss: 0.1457 - val_binary_accuracy: 0.9455
# Epoch 51/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1525 - binary_accuracy: 0.9417 - val_loss: 0.1252 - val_binary_accuracy: 0.9548
# Epoch 52/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1489 - binary_accuracy: 0.9428 - val_loss: 0.1345 - val_binary_accuracy: 0.9498
# Epoch 53/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1471 - binary_accuracy: 0.9435 - val_loss: 0.1564 - val_binary_accuracy: 0.9418
# Epoch 54/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1442 - binary_accuracy: 0.9451 - val_loss: 0.1272 - val_binary_accuracy: 0.9500
# Epoch 55/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1423 - binary_accuracy: 0.9445 - val_loss: 0.1272 - val_binary_accuracy: 0.9528
# Epoch 56/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1451 - binary_accuracy: 0.9442 - val_loss: 0.1167 - val_binary_accuracy: 0.9563
# Epoch 57/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1401 - binary_accuracy: 0.9463 - val_loss: 0.1180 - val_binary_accuracy: 0.9569
# Epoch 58/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1348 - binary_accuracy: 0.9488 - val_loss: 0.1172 - val_binary_accuracy: 0.9557
# Epoch 59/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1352 - binary_accuracy: 0.9480 - val_loss: 0.1150 - val_binary_accuracy: 0.9549
# Epoch 60/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1314 - binary_accuracy: 0.9499 - val_loss: 0.1133 - val_binary_accuracy: 0.9564
# Epoch 61/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1319 - binary_accuracy: 0.9489 - val_loss: 0.1224 - val_binary_accuracy: 0.9529
# Epoch 62/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.3220 - binary_accuracy: 0.9013 - val_loss: 1.2365 - val_binary_accuracy: 0.7449
# Epoch 63/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.3417 - binary_accuracy: 0.8750 - val_loss: 0.2892 - val_binary_accuracy: 0.8862
# Epoch 64/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2967 - binary_accuracy: 0.8875 - val_loss: 0.4272 - val_binary_accuracy: 0.8370
# Epoch 65/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2624 - binary_accuracy: 0.8974 - val_loss: 0.3436 - val_binary_accuracy: 0.8600
# Epoch 66/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2467 - binary_accuracy: 0.9049 - val_loss: 0.2746 - val_binary_accuracy: 0.8888
# Epoch 67/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2343 - binary_accuracy: 0.9086 - val_loss: 0.2583 - val_binary_accuracy: 0.8929
# Epoch 68/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2205 - binary_accuracy: 0.9144 - val_loss: 0.2917 - val_binary_accuracy: 0.8713
# Epoch 69/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2105 - binary_accuracy: 0.9174 - val_loss: 0.2651 - val_binary_accuracy: 0.8828
# Epoch 70/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.2038 - binary_accuracy: 0.9190 - val_loss: 0.1787 - val_binary_accuracy: 0.9305
# Epoch 71/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1969 - binary_accuracy: 0.9231 - val_loss: 0.2123 - val_binary_accuracy: 0.9199
# Epoch 72/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1900 - binary_accuracy: 0.9260 - val_loss: 0.1737 - val_binary_accuracy: 0.9373
# Epoch 73/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1851 - binary_accuracy: 0.9276 - val_loss: 0.1564 - val_binary_accuracy: 0.9391
# Epoch 74/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1766 - binary_accuracy: 0.9317 - val_loss: 0.1524 - val_binary_accuracy: 0.9428
# Epoch 75/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1734 - binary_accuracy: 0.9323 - val_loss: 0.1724 - val_binary_accuracy: 0.9370
# Epoch 76/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1667 - binary_accuracy: 0.9348 - val_loss: 0.1530 - val_binary_accuracy: 0.9421
# Epoch 77/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1635 - binary_accuracy: 0.9367 - val_loss: 0.1681 - val_binary_accuracy: 0.9347
# Epoch 78/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1663 - binary_accuracy: 0.9353 - val_loss: 0.1442 - val_binary_accuracy: 0.9420
# Epoch 79/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1603 - binary_accuracy: 0.9377 - val_loss: 0.1382 - val_binary_accuracy: 0.9477
# Epoch 80/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1576 - binary_accuracy: 0.9383 - val_loss: 0.1514 - val_binary_accuracy: 0.9415
# Epoch 81/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1541 - binary_accuracy: 0.9399 - val_loss: 0.1327 - val_binary_accuracy: 0.9500
# Epoch 82/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1490 - binary_accuracy: 0.9419 - val_loss: 0.1478 - val_binary_accuracy: 0.9449
# Epoch 83/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1485 - binary_accuracy: 0.9433 - val_loss: 0.1224 - val_binary_accuracy: 0.9523
# Epoch 84/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1446 - binary_accuracy: 0.9447 - val_loss: 0.1277 - val_binary_accuracy: 0.9526
# Epoch 85/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1433 - binary_accuracy: 0.9452 - val_loss: 0.1287 - val_binary_accuracy: 0.9500
# Epoch 86/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1414 - binary_accuracy: 0.9454 - val_loss: 0.1365 - val_binary_accuracy: 0.9477
# Epoch 87/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1378 - binary_accuracy: 0.9481 - val_loss: 0.1169 - val_binary_accuracy: 0.9551
# Epoch 88/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1364 - binary_accuracy: 0.9476 - val_loss: 0.1248 - val_binary_accuracy: 0.9528
# Epoch 89/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1358 - binary_accuracy: 0.9485 - val_loss: 0.1209 - val_binary_accuracy: 0.9529
# Epoch 90/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1342 - binary_accuracy: 0.9493 - val_loss: 0.1200 - val_binary_accuracy: 0.9534
# Epoch 91/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1302 - binary_accuracy: 0.9503 - val_loss: 0.1182 - val_binary_accuracy: 0.9553
# Epoch 92/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1791 - binary_accuracy: 0.9337 - val_loss: 0.4199 - val_binary_accuracy: 0.8539
# Epoch 93/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1766 - binary_accuracy: 0.9325 - val_loss: 0.1446 - val_binary_accuracy: 0.9436
# Epoch 94/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1521 - binary_accuracy: 0.9411 - val_loss: 0.1285 - val_binary_accuracy: 0.9487
# Epoch 95/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1401 - binary_accuracy: 0.9463 - val_loss: 0.1266 - val_binary_accuracy: 0.9517
# Epoch 96/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1315 - binary_accuracy: 0.9495 - val_loss: 0.1183 - val_binary_accuracy: 0.9541
# Epoch 97/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1365 - binary_accuracy: 0.9472 - val_loss: 0.1336 - val_binary_accuracy: 0.9456
# Epoch 98/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1287 - binary_accuracy: 0.9506 - val_loss: 0.1270 - val_binary_accuracy: 0.9520
# Epoch 99/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1265 - binary_accuracy: 0.9510 - val_loss: 0.1169 - val_binary_accuracy: 0.9562
# Epoch 100/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1223 - binary_accuracy: 0.9525 - val_loss: 0.1183 - val_binary_accuracy: 0.9564
# Epoch 101/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1236 - binary_accuracy: 0.9525 - val_loss: 0.1096 - val_binary_accuracy: 0.9582
# Epoch 102/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1194 - binary_accuracy: 0.9552 - val_loss: 0.1174 - val_binary_accuracy: 0.9541
# Epoch 103/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1195 - binary_accuracy: 0.9542 - val_loss: 0.1115 - val_binary_accuracy: 0.9589
# Epoch 104/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1172 - binary_accuracy: 0.9547 - val_loss: 0.1096 - val_binary_accuracy: 0.9585
# Epoch 105/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1166 - binary_accuracy: 0.9550 - val_loss: 0.1046 - val_binary_accuracy: 0.9598
# Epoch 106/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1136 - binary_accuracy: 0.9565 - val_loss: 0.1101 - val_binary_accuracy: 0.9595
# Epoch 107/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1112 - binary_accuracy: 0.9571 - val_loss: 0.1031 - val_binary_accuracy: 0.9607
# Epoch 108/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1112 - binary_accuracy: 0.9583 - val_loss: 0.1201 - val_binary_accuracy: 0.9568
# Epoch 109/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1128 - binary_accuracy: 0.9556 - val_loss: 0.1096 - val_binary_accuracy: 0.9602
# Epoch 110/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1077 - binary_accuracy: 0.9593 - val_loss: 0.1006 - val_binary_accuracy: 0.9623
# Epoch 111/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1065 - binary_accuracy: 0.9601 - val_loss: 0.1081 - val_binary_accuracy: 0.9586
# Epoch 112/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1064 - binary_accuracy: 0.9597 - val_loss: 0.1002 - val_binary_accuracy: 0.9619
# Epoch 113/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1057 - binary_accuracy: 0.9600 - val_loss: 0.1016 - val_binary_accuracy: 0.9624
# Epoch 114/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1035 - binary_accuracy: 0.9608 - val_loss: 0.0993 - val_binary_accuracy: 0.9633
# Epoch 115/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1046 - binary_accuracy: 0.9606 - val_loss: 0.1127 - val_binary_accuracy: 0.9574
# Epoch 116/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1013 - binary_accuracy: 0.9618 - val_loss: 0.1027 - val_binary_accuracy: 0.9619
# Epoch 117/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.1017 - binary_accuracy: 0.9616 - val_loss: 0.0995 - val_binary_accuracy: 0.9619
# Epoch 118/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0979 - binary_accuracy: 0.9633 - val_loss: 0.1016 - val_binary_accuracy: 0.9630
# Epoch 119/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0976 - binary_accuracy: 0.9625 - val_loss: 0.1023 - val_binary_accuracy: 0.9616
# Epoch 120/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0952 - binary_accuracy: 0.9638 - val_loss: 0.1044 - val_binary_accuracy: 0.9607
# Epoch 121/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0958 - binary_accuracy: 0.9633 - val_loss: 0.0992 - val_binary_accuracy: 0.9624
# Epoch 122/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0930 - binary_accuracy: 0.9645 - val_loss: 0.0983 - val_binary_accuracy: 0.9642
# Epoch 123/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0930 - binary_accuracy: 0.9657 - val_loss: 0.0952 - val_binary_accuracy: 0.9650
# Epoch 124/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0928 - binary_accuracy: 0.9657 - val_loss: 0.0944 - val_binary_accuracy: 0.9658
# Epoch 125/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0931 - binary_accuracy: 0.9643 - val_loss: 0.0993 - val_binary_accuracy: 0.9633
# Epoch 126/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0899 - binary_accuracy: 0.9664 - val_loss: 0.1018 - val_binary_accuracy: 0.9634
# Epoch 127/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0898 - binary_accuracy: 0.9658 - val_loss: 0.1070 - val_binary_accuracy: 0.9601
# Epoch 128/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0887 - binary_accuracy: 0.9664 - val_loss: 0.1161 - val_binary_accuracy: 0.9594
# Epoch 129/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0900 - binary_accuracy: 0.9659 - val_loss: 0.0943 - val_binary_accuracy: 0.9656
# Epoch 130/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0878 - binary_accuracy: 0.9668 - val_loss: 0.0923 - val_binary_accuracy: 0.9664
# Epoch 131/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0851 - binary_accuracy: 0.9678 - val_loss: 0.0926 - val_binary_accuracy: 0.9647
# Epoch 132/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0861 - binary_accuracy: 0.9680 - val_loss: 0.0971 - val_binary_accuracy: 0.9647
# Epoch 133/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0859 - binary_accuracy: 0.9666 - val_loss: 0.0949 - val_binary_accuracy: 0.9673
# Epoch 134/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0822 - binary_accuracy: 0.9692 - val_loss: 0.0961 - val_binary_accuracy: 0.9647
# Epoch 135/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0830 - binary_accuracy: 0.9680 - val_loss: 0.0907 - val_binary_accuracy: 0.9664
# Epoch 136/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0848 - binary_accuracy: 0.9677 - val_loss: 0.1001 - val_binary_accuracy: 0.9627
# Epoch 137/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0843 - binary_accuracy: 0.9681 - val_loss: 0.0914 - val_binary_accuracy: 0.9667
# Epoch 138/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0842 - binary_accuracy: 0.9681 - val_loss: 0.0916 - val_binary_accuracy: 0.9676
# Epoch 139/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0816 - binary_accuracy: 0.9691 - val_loss: 0.0949 - val_binary_accuracy: 0.9665
# Epoch 140/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0819 - binary_accuracy: 0.9687 - val_loss: 0.0904 - val_binary_accuracy: 0.9679
# Epoch 141/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0767 - binary_accuracy: 0.9705 - val_loss: 0.0873 - val_binary_accuracy: 0.9684
# Epoch 142/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0800 - binary_accuracy: 0.9703 - val_loss: 0.0965 - val_binary_accuracy: 0.9652
# Epoch 143/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0787 - binary_accuracy: 0.9707 - val_loss: 0.0894 - val_binary_accuracy: 0.9684
# Epoch 144/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0734 - binary_accuracy: 0.9732 - val_loss: 0.0871 - val_binary_accuracy: 0.9698
# Epoch 145/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0751 - binary_accuracy: 0.9718 - val_loss: 0.0924 - val_binary_accuracy: 0.9682
# Epoch 146/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0727 - binary_accuracy: 0.9725 - val_loss: 0.0969 - val_binary_accuracy: 0.9647
# Epoch 147/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0767 - binary_accuracy: 0.9713 - val_loss: 0.0866 - val_binary_accuracy: 0.9681
# Epoch 148/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0739 - binary_accuracy: 0.9719 - val_loss: 0.0929 - val_binary_accuracy: 0.9672
# Epoch 149/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0753 - binary_accuracy: 0.9713 - val_loss: 0.1015 - val_binary_accuracy: 0.9640
# Epoch 150/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0729 - binary_accuracy: 0.9733 - val_loss: 0.0868 - val_binary_accuracy: 0.9686
# Epoch 151/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0710 - binary_accuracy: 0.9730 - val_loss: 0.0970 - val_binary_accuracy: 0.9640
# Epoch 152/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0753 - binary_accuracy: 0.9713 - val_loss: 0.0897 - val_binary_accuracy: 0.9676
# Epoch 153/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0729 - binary_accuracy: 0.9729 - val_loss: 0.0934 - val_binary_accuracy: 0.9672
# Epoch 154/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0724 - binary_accuracy: 0.9722 - val_loss: 0.0866 - val_binary_accuracy: 0.9685
# Epoch 155/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0688 - binary_accuracy: 0.9736 - val_loss: 0.0836 - val_binary_accuracy: 0.9699
# Epoch 156/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0659 - binary_accuracy: 0.9753 - val_loss: 0.0839 - val_binary_accuracy: 0.9710
# Epoch 157/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0688 - binary_accuracy: 0.9738 - val_loss: 0.0931 - val_binary_accuracy: 0.9664
# Epoch 158/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0721 - binary_accuracy: 0.9728 - val_loss: 0.0948 - val_binary_accuracy: 0.9663
# Epoch 159/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0700 - binary_accuracy: 0.9740 - val_loss: 0.0915 - val_binary_accuracy: 0.9675
# Epoch 160/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0691 - binary_accuracy: 0.9737 - val_loss: 0.0883 - val_binary_accuracy: 0.9708
# Epoch 161/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0676 - binary_accuracy: 0.9751 - val_loss: 0.0838 - val_binary_accuracy: 0.9708
# Epoch 162/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0644 - binary_accuracy: 0.9767 - val_loss: 0.0874 - val_binary_accuracy: 0.9697
# Epoch 163/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0638 - binary_accuracy: 0.9760 - val_loss: 0.0863 - val_binary_accuracy: 0.9704
# Epoch 164/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0673 - binary_accuracy: 0.9751 - val_loss: 0.0861 - val_binary_accuracy: 0.9695
# Epoch 165/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0671 - binary_accuracy: 0.9758 - val_loss: 0.0890 - val_binary_accuracy: 0.9692
# Epoch 166/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0646 - binary_accuracy: 0.9762 - val_loss: 0.0874 - val_binary_accuracy: 0.9687
# Epoch 167/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0608 - binary_accuracy: 0.9775 - val_loss: 0.0815 - val_binary_accuracy: 0.9692
# Epoch 168/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0643 - binary_accuracy: 0.9764 - val_loss: 0.0886 - val_binary_accuracy: 0.9690
# Epoch 169/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0599 - binary_accuracy: 0.9771 - val_loss: 0.0883 - val_binary_accuracy: 0.9685
# Epoch 170/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0647 - binary_accuracy: 0.9754 - val_loss: 0.0838 - val_binary_accuracy: 0.9699
# Epoch 171/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0613 - binary_accuracy: 0.9770 - val_loss: 0.0905 - val_binary_accuracy: 0.9684
# Epoch 172/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0616 - binary_accuracy: 0.9773 - val_loss: 0.0963 - val_binary_accuracy: 0.9677
# Epoch 173/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0591 - binary_accuracy: 0.9773 - val_loss: 0.0865 - val_binary_accuracy: 0.9698
# Epoch 174/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0584 - binary_accuracy: 0.9782 - val_loss: 0.0887 - val_binary_accuracy: 0.9700
# Epoch 175/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0606 - binary_accuracy: 0.9775 - val_loss: 0.0910 - val_binary_accuracy: 0.9698
# Epoch 176/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0609 - binary_accuracy: 0.9774 - val_loss: 0.0844 - val_binary_accuracy: 0.9712
# Epoch 177/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0585 - binary_accuracy: 0.9789 - val_loss: 0.0859 - val_binary_accuracy: 0.9711
# Epoch 178/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0601 - binary_accuracy: 0.9777 - val_loss: 0.0782 - val_binary_accuracy: 0.9730
# Epoch 179/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0565 - binary_accuracy: 0.9797 - val_loss: 0.0892 - val_binary_accuracy: 0.9698
# Epoch 180/300
# 86/86 [==============================] - 7s 82ms/step - loss: 0.0581 - binary_accuracy: 0.9784 - val_loss: 0.0831 - val_binary_accuracy: 0.9715
# Epoch 181/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0591 - binary_accuracy: 0.9785 - val_loss: 0.0853 - val_binary_accuracy: 0.9701
# Epoch 182/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0577 - binary_accuracy: 0.9791 - val_loss: 0.0971 - val_binary_accuracy: 0.9688
# Epoch 183/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0584 - binary_accuracy: 0.9783 - val_loss: 0.0894 - val_binary_accuracy: 0.9710
# Epoch 184/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0568 - binary_accuracy: 0.9799 - val_loss: 0.0806 - val_binary_accuracy: 0.9719
# Epoch 185/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0545 - binary_accuracy: 0.9801 - val_loss: 0.0849 - val_binary_accuracy: 0.9698
# Epoch 186/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0570 - binary_accuracy: 0.9787 - val_loss: 0.0826 - val_binary_accuracy: 0.9706
# Epoch 187/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0520 - binary_accuracy: 0.9812 - val_loss: 0.0839 - val_binary_accuracy: 0.9716
# Epoch 188/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0565 - binary_accuracy: 0.9788 - val_loss: 0.0828 - val_binary_accuracy: 0.9718
# Epoch 189/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0538 - binary_accuracy: 0.9809 - val_loss: 0.0863 - val_binary_accuracy: 0.9709
# Epoch 190/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0518 - binary_accuracy: 0.9806 - val_loss: 0.0834 - val_binary_accuracy: 0.9719
# Epoch 191/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0523 - binary_accuracy: 0.9811 - val_loss: 0.0866 - val_binary_accuracy: 0.9710
# Epoch 192/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0541 - binary_accuracy: 0.9799 - val_loss: 0.0817 - val_binary_accuracy: 0.9723
# Epoch 193/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0483 - binary_accuracy: 0.9827 - val_loss: 0.0949 - val_binary_accuracy: 0.9669
# Epoch 194/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0515 - binary_accuracy: 0.9813 - val_loss: 0.0843 - val_binary_accuracy: 0.9712
# Epoch 195/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0538 - binary_accuracy: 0.9807 - val_loss: 0.0824 - val_binary_accuracy: 0.9714
# Epoch 196/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0524 - binary_accuracy: 0.9808 - val_loss: 0.0865 - val_binary_accuracy: 0.9714
# Epoch 197/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0503 - binary_accuracy: 0.9811 - val_loss: 0.0868 - val_binary_accuracy: 0.9715
# Epoch 198/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0513 - binary_accuracy: 0.9813 - val_loss: 0.0893 - val_binary_accuracy: 0.9698
# Epoch 199/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0501 - binary_accuracy: 0.9815 - val_loss: 0.0913 - val_binary_accuracy: 0.9708
# Epoch 200/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0479 - binary_accuracy: 0.9823 - val_loss: 0.0889 - val_binary_accuracy: 0.9706
# Epoch 201/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0484 - binary_accuracy: 0.9821 - val_loss: 0.0896 - val_binary_accuracy: 0.9698
# Epoch 202/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0495 - binary_accuracy: 0.9807 - val_loss: 0.1137 - val_binary_accuracy: 0.9655
# Epoch 203/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0505 - binary_accuracy: 0.9817 - val_loss: 0.0836 - val_binary_accuracy: 0.9730
# Epoch 204/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0489 - binary_accuracy: 0.9823 - val_loss: 0.0821 - val_binary_accuracy: 0.9734
# Epoch 205/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0470 - binary_accuracy: 0.9833 - val_loss: 0.0838 - val_binary_accuracy: 0.9715
# Epoch 206/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0455 - binary_accuracy: 0.9836 - val_loss: 0.0858 - val_binary_accuracy: 0.9713
# Epoch 207/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0478 - binary_accuracy: 0.9825 - val_loss: 0.0851 - val_binary_accuracy: 0.9709
# Epoch 208/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0436 - binary_accuracy: 0.9842 - val_loss: 0.0874 - val_binary_accuracy: 0.9700
# Epoch 209/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0482 - binary_accuracy: 0.9828 - val_loss: 0.0878 - val_binary_accuracy: 0.9715
# Epoch 210/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0455 - binary_accuracy: 0.9838 - val_loss: 0.0850 - val_binary_accuracy: 0.9727
# Epoch 211/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0438 - binary_accuracy: 0.9841 - val_loss: 0.0811 - val_binary_accuracy: 0.9729
# Epoch 212/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0469 - binary_accuracy: 0.9831 - val_loss: 0.0878 - val_binary_accuracy: 0.9726
# Epoch 213/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0462 - binary_accuracy: 0.9830 - val_loss: 0.0839 - val_binary_accuracy: 0.9718
# Epoch 214/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0432 - binary_accuracy: 0.9842 - val_loss: 0.0854 - val_binary_accuracy: 0.9716
# Epoch 215/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0466 - binary_accuracy: 0.9828 - val_loss: 0.0936 - val_binary_accuracy: 0.9708
# Epoch 216/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0417 - binary_accuracy: 0.9848 - val_loss: 0.0817 - val_binary_accuracy: 0.9733
# Epoch 217/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0443 - binary_accuracy: 0.9847 - val_loss: 0.0942 - val_binary_accuracy: 0.9696
# Epoch 218/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0464 - binary_accuracy: 0.9834 - val_loss: 0.1038 - val_binary_accuracy: 0.9678
# Epoch 219/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0418 - binary_accuracy: 0.9855 - val_loss: 0.0899 - val_binary_accuracy: 0.9705
# Epoch 220/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0429 - binary_accuracy: 0.9846 - val_loss: 0.0814 - val_binary_accuracy: 0.9740
# Epoch 221/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0426 - binary_accuracy: 0.9849 - val_loss: 0.0884 - val_binary_accuracy: 0.9716
# Epoch 222/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0438 - binary_accuracy: 0.9841 - val_loss: 0.0876 - val_binary_accuracy: 0.9711
# Epoch 223/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0432 - binary_accuracy: 0.9850 - val_loss: 0.0831 - val_binary_accuracy: 0.9736
# Epoch 224/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0417 - binary_accuracy: 0.9850 - val_loss: 0.0899 - val_binary_accuracy: 0.9719
# Epoch 225/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0442 - binary_accuracy: 0.9837 - val_loss: 0.0802 - val_binary_accuracy: 0.9736
# Epoch 226/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0404 - binary_accuracy: 0.9856 - val_loss: 0.0802 - val_binary_accuracy: 0.9739
# Epoch 227/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0402 - binary_accuracy: 0.9854 - val_loss: 0.0784 - val_binary_accuracy: 0.9734
# Epoch 228/300
# 86/86 [==============================] - 7s 81ms/step - loss: 0.0414 - binary_accuracy: 0.9851 - val_loss: 0.0879 - val_binary_accuracy: 0.9731
# 37/37 [==============================] - 6s 83ms/step - loss: 0.0886 - binary_accuracy: 0.9696
# Test accuracy: 0.9695580005645752
